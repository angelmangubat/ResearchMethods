# %% [markdown]
# **Pedestrian Detection Using SVM method**

# %%
#Map google drive and the input and output files
from google.colab import drive
drive.mount('/content/drive')
Input_Path = "/content/drive/My Drive/App/ResearchMethods/input/"
TestPath = "/content/drive/My Drive/App/ResearchMethods/input/Test/JPEGImages/"
ValPath = "/content/drive/My Drive/App/ResearchMethods/input/Val/JPEGImages/"
TrainPath = "/content/drive/My Drive/App/ResearchMethods/input/Train/JPEGImages/"
TestMePath = "/content/drive/My Drive/App/ResearchMethods/input/TestMe/"
ModelPath = "/content/drive/My Drive/App/ResearchMethods/model/"
Output_Path = "/content/drive/My Drive/App/ResearchMethods/output/"

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import cv2

# List all files under the input directory
import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
for dirname, _, filenames in os.walk(TrainPath):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# Import the Input images using a loop function that catches all images in JPG format.

# %%
#Import the Images
files = os.listdir(TestMePath)
print(files)
img_path_list = []
for f in files:
    if f.endswith(".jpg"):
        img_path_list.append(f)
print(img_path_list)
# Out:
# ['8.jpg', '1.jpg', '2.jpg', '3.jpg', '4.jpg', '12.jpg', '7.jpg', '11.jpg', '5.jpg', '6.jpg', '10.jpg', '9.jpg']
# ['8.jpg', '1.jpg', '2.jpg', '3.jpg', '4.jpg', '12.jpg', '7.jpg', '11.jpg', '5.jpg', '6.jpg', '10.jpg', '9.jpg']

# %% [markdown]
# Use SVM classifier

# %%
#Use of HOG Identifier
hog = cv2.HOGDescriptor()
#Add SVM descriptor
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# %% [markdown]
# Steps:
# 1.   Import images using imread function.
# 2.   Detect pedestrians with HOG descriptor. Also, used scalefactor and minNeighbors parameters for fine tuning. The (8,8) padding ensures that the size of the image does not change by adding 0s to the edges of the image.
# 3.   Draw a rectangle on the pedestrians found and display them on the screen.

# %%
#a="/kaggle/input/pedestrian/"
a=TestMePath
for imagePath in img_path_list:
    print(imagePath)

    image = cv2.imread(a+imagePath)
    image=cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    (rects, weights) = hog.detectMultiScale(image, padding = (8,8), scale = 1.01)

    for (i,(x,y,w,h)) in enumerate(rects):
        cv2.rectangle(image, (x,y),(x+w,y+h),(0,0,255),2)
        cv2.putText(image, "Pedestrian {}".format(i+1), (x,y-10),cv2.FONT_HERSHEY_SIMPLEX, 0.55, (0,255,255),2)
    plt.figure(),plt.imshow(image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Algorithm Reference: https://www.kaggle.com/code/cengizalbayrak/yaya-tespiti-pedestrian-detection
#
# Dataset Reference: https://www.kaggle.com/datasets/karthika95/pedestrian-detection/data
